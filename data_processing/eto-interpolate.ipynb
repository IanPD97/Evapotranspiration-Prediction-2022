# %%
import pandas as pd

# %%
RUTA = '/content/drive/MyDrive/Universidad/Evapotranspiration-Prediction-2022/data_processing/data/Eto-Pudahuel.csv'
eto = pd.read_csv(RUTA)

# %%
eto = eto.set_index('Data')
eto = eto[['Eto']]
eto = eto.interpolate()

# %%
eto.to_csv(RUTA)
